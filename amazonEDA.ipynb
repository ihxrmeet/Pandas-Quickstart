# %% [markdown]
# <a href="https://colab.research.google.com/github/ihxrmeet/Pandas-Quickstart/blob/main/amazonEDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import opendatasets as od
# %matplotlib inline

# %%
raw_data = pd.read_csv('/content/unlock-profits-with-e-commerce-sales-data/Amazon Sale Report.csv', low_memory=False)

# %%
df = raw_data.copy()

# %%
df.head(2)
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
#
#   Category  ... currency  Amount  ship-city   ship-state ship-postal-code  \
# 0      Set  ...      INR  647.62     MUMBAI  MAHARASHTRA         400081.0
# 1    kurta  ...      INR  406.00  BENGALURU    KARNATAKA         560085.0
#
#    ship-country                                      promotion-ids    B2B  \
# 0            IN                                                NaN  False
# 1            IN  Amazon PLCC Free-Financing Universal Merchant ...  False
#
#    fulfilled-by Unnamed: 22
# 0     Easy Ship         NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
# ...

# %% [markdown]
# ---
#
#
#
# ---
#
#
# **1. Sales and Revenue Analysis:**
# - **Q1:** What are the top-selling products or categories by revenue?
# - **Q2:** How does sales performance vary across different sales channels or fulfillment methods?
# - **Q3:** Can we identify any seasonal trends or patterns in sales based on order dates?
#
#
# ---
#
#
# **2. Customer Insights:**
#
# - **Q4:** Who are our most valuable customers based on total purchase amount?
# - **Q5:** How does customer purchasing behavior differ between new and returning customers?
# - **Q6:** Are there any correlations between customer demographics (like location) and purchasing patterns?
#
#
# ---
#
#
# **3. Operational Efficiency:**
# - **Q7:** What is the average fulfillment time for orders, and how does it impact customer satisfaction?
# - **Q8:** Is there any correlation between order size (quantity of items) and fulfillment efficiency?
# - **Q9:** Are there any inefficiencies in the shipping process based on courier status or shipping service levels?
#
#
# ---
#
#
# **4. Marketing and Promotions:**
# - **Q10:** Which promotions or sales channels generate the highest return on investment (ROI)?
# - **Q11:** How effective are different marketing campaigns in driving sales, based on promotional IDs?
# - **Q12:** Can we identify any cross-selling opportunities based on product category associations?
#
#
# ---
#
#
# **5. Financial Performance:**
# - **Q13:** What is the profitability of different product categories or SKU variants after accounting for fulfillment and shipping costs?
# - **Q14:** How does currency exchange rates impact revenue and profitability across different regions?
# - **Q15:** Are there any cost-saving opportunities in fulfillment strategies based on sales volume or order characteristics?
#
#
# ---
#
#
#
# ---

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22', 'Sales Channel'],
#       dtype='object')
